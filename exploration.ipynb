# %% [markdown]
# <a href="https://colab.research.google.com/github/DenZet18/football-talent-compression/blob/main/exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Talent Distribution Compression – Exploration

## EPL Prototype (2000–2005)

## Ceiling Metrics – Sanity Checks

## Floor Metrics – Sanity Checks
